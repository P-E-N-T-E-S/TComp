# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from google.colab import files

#Pior Caso Insertion

uploaded = files.upload()

df = pd.read_csv(list(uploaded.keys())[0])

def plot_quadratico(df):
    plt.figure(figsize=(12, 6))
    plt.scatter(df['Tamanho da lista'], df['Tempo Médio (s)'], color='skyblue', alpha=0.7, edgecolor='black', label='Pontos Individuais')

    z = np.polyfit(df['Tamanho da lista'], df['Tempo Médio (s)'], 2)
    p = np.poly1d(z)

    x_fit = np.linspace(df['Tamanho da lista'].min(), df['Tamanho da lista'].max(), 100)
    plt.plot(x_fit, p(x_fit), color='red', linestyle='--', linewidth=2, label='Linha de Tendência Quadrática')

    plt.title('Relação Quadrática entre Tamanho da Lista e Tempo de Execução', fontsize=16, weight='bold')
    plt.xlabel('Tamanho da Lista', fontsize=14)
    plt.ylabel('Tempo Médio (s)', fontsize=14)
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.legend()
    plt.tight_layout()
    plt.show()

plot_quadratico(df)
# Out:
#      <input type="file" id="files-3ae5ab87-69c8-430c-a9c3-0da1d4e062a3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3ae5ab87-69c8-430c-a9c3-0da1d4e062a3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
def calcula_media_tempo(df):
    media_df = df.groupby('Tamanho da lista')['Tempo Médio (s)'].mean().reset_index()
    return media_df

def plot_barras_media_com_tendencia(df):
    media_df = calcula_media_tempo(df)

    fig, ax = plt.subplots(figsize=(10, 6))
    colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd']
    bars = ax.bar(media_df['Tamanho da lista'], media_df['Tempo Médio (s)'], color=colors, edgecolor='black')

    for bar, tempo in zip(bars, media_df['Tempo Médio (s)']):
        ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.02, f'{tempo:.2f}',
                ha='center', va='bottom', fontsize=12, fontweight='bold', color='black')

    z = np.polyfit(media_df['Tamanho da lista'], media_df['Tempo Médio (s)'], 2)
    p = np.poly1d(z)

    x_fit = np.linspace(media_df['Tamanho da lista'].min(), media_df['Tamanho da lista'].max(), 100)
    ax.plot(x_fit, p(x_fit), color='red', linestyle='--', linewidth=2, label='Linha de Tendência Quadrática')

    ax.set_xlabel('Tamanho da Lista', fontsize=14)
    ax.set_ylabel('Tempo Médio (s)', fontsize=14)
    ax.set_title('Média do Tempo por Tamanho da Lista com Linha de Tendência', fontsize=16, fontweight='bold', pad=20)

    ax.set_ylim(0, media_df['Tempo Médio (s)'].max() * 1.4)

    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_linewidth(0.8)
    ax.spines['bottom'].set_linewidth(0.8)
    ax.grid(axis='y', linestyle='--', alpha=0.7)
    ax.legend()

    plt.tight_layout()
    plt.show()

plot_barras_media_com_tendencia(df)

# %%
#Caso Médio Insertion
uploaded = files.upload()

df = pd.read_csv(list(uploaded.keys())[0])

def plot_quadratico(df):
    plt.figure(figsize=(12, 6))
    plt.scatter(df['Tamanho da lista'], df['Tempo Médio (s)'], color='skyblue', alpha=0.7, edgecolor='black', label='Pontos Individuais')

    z = np.polyfit(df['Tamanho da lista'], df['Tempo Médio (s)'], 2)
    p = np.poly1d(z)

    x_fit = np.linspace(df['Tamanho da lista'].min(), df['Tamanho da lista'].max(), 100)
    plt.plot(x_fit, p(x_fit), color='red', linestyle='--', linewidth=2, label='Linha de Tendência Quadrática')

    plt.title('Relação Quadrática entre Tamanho da Lista e Tempo de Execução', fontsize=16, weight='bold')
    plt.xlabel('Tamanho da Lista', fontsize=14)
    plt.ylabel('Tempo Médio (s)', fontsize=14)
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.legend()
    plt.tight_layout()
    plt.show()

plot_quadratico(df)
# Out:
#      <input type="file" id="files-568d0c57-7178-4353-8e2f-c2291211f733" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-568d0c57-7178-4353-8e2f-c2291211f733">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
def calcula_media_tempo(df):
    media_df = df.groupby('Tamanho da lista')['Tempo Médio (s)'].mean().reset_index()
    return media_df

def plot_barras_media_com_tendencia(df):
    media_df = calcula_media_tempo(df)

    fig, ax = plt.subplots(figsize=(10, 6))
    colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd']
    bars = ax.bar(media_df['Tamanho da lista'], media_df['Tempo Médio (s)'], color=colors, edgecolor='black')

    for bar, tempo in zip(bars, media_df['Tempo Médio (s)']):
        ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.02, f'{tempo:.2f}',
                ha='center', va='bottom', fontsize=12, fontweight='bold', color='black')

    z = np.polyfit(media_df['Tamanho da lista'], media_df['Tempo Médio (s)'], 2)
    p = np.poly1d(z)

    x_fit = np.linspace(media_df['Tamanho da lista'].min(), media_df['Tamanho da lista'].max(), 100)
    ax.plot(x_fit, p(x_fit), color='red', linestyle='--', linewidth=2, label='Linha de Tendência Quadrática')

    ax.set_xlabel('Tamanho da Lista', fontsize=14)
    ax.set_ylabel('Tempo Médio (s)', fontsize=14)
    ax.set_title('Média do Tempo por Tamanho da Lista com Linha de Tendência', fontsize=16, fontweight='bold', pad=20)

    ax.set_ylim(0, media_df['Tempo Médio (s)'].max() * 1.4)

    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_linewidth(0.8)
    ax.spines['bottom'].set_linewidth(0.8)
    ax.grid(axis='y', linestyle='--', alpha=0.7)
    ax.legend()

    plt.tight_layout()
    plt.show()

plot_barras_media_com_tendencia(df)

# %%
#Pior Caso Merge

uploaded = files.upload()
df = pd.read_csv(list(uploaded.keys())[0])

def plot_quadratico(df):
    plt.figure(figsize=(12, 6))
    plt.scatter(df['Tamanho da lista'], df['Tempo Médio (s)'], color='skyblue', alpha=0.7, edgecolor='black', label='Pontos Individuais')

    z = np.polyfit(df['Tamanho da lista'], df['Tempo Médio (s)'], 2)
    p = np.poly1d(z)

    x_fit = np.linspace(df['Tamanho da lista'].min(), df['Tamanho da lista'].max(), 100)
    plt.plot(x_fit, p(x_fit), color='red', linestyle='--', linewidth=2, label='Linha de Tendência')

    plt.title('Relação Quadrática entre Tamanho da Lista e Tempo de Execução', fontsize=16, weight='bold')
    plt.xlabel('Tamanho da Lista', fontsize=14)
    plt.ylabel('Tempo Médio (s)', fontsize=14)
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.legend()
    plt.tight_layout()
    plt.show()

plot_quadratico(df)
# Out:
#      <input type="file" id="files-262b2701-8a68-4294-9b7c-a7b0cb94423e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-262b2701-8a68-4294-9b7c-a7b0cb94423e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
def calcula_media_tempo(df):
    media_df = df.groupby('Tamanho da lista')['Tempo Médio (s)'].mean().reset_index()
    return media_df

def plot_barras_com_tendencia(df):
    media_df = calcula_media_tempo(df)

    fig, ax = plt.subplots(figsize=(12, 6))

    bars = ax.bar(media_df['Tamanho da lista'], media_df['Tempo Médio (s)'], color='#1f77b4', edgecolor='black')

    z = np.polyfit(media_df['Tamanho da lista'], media_df['Tempo Médio (s)'], 2)
    p = np.poly1d(z)

    x_fit = np.linspace(media_df['Tamanho da lista'].min(), media_df['Tamanho da lista'].max(), 100)
    ax.plot(x_fit, p(x_fit), color='red', linestyle='--', linewidth=2, label='Linha de Tendência')

    ax.set_xlabel('Tamanho da Lista', fontsize=14)
    ax.set_title('Média do Tempo por Tamanho da Lista com Linha de Tendência', fontsize=16, fontweight='bold')

    ax.set_ylim(0, media_df['Tempo Médio (s)'].max() * 1.4)

    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_linewidth(0.8)
    ax.spines['bottom'].set_linewidth(0.8)
    ax.grid(axis='y', linestyle='--', alpha=0.7)

    ax.legend()

    plt.subplots_adjust(top=0.95, bottom=0.15, left=0.1, right=0.9)
    plt.show()

plot_barras_com_tendencia(df)

# %%
#Caso Médio Merge

uploaded = files.upload()
df = pd.read_csv(list(uploaded.keys())[0])

def plot_quadratico(df):
    plt.figure(figsize=(12, 6))
    plt.scatter(df['Tamanho da lista'], df['Tempo Médio (s)'], color='skyblue', alpha=0.7, edgecolor='black', label='Pontos Individuais')

    z = np.polyfit(df['Tamanho da lista'], df['Tempo Médio (s)'], 2)
    p = np.poly1d(z)

    x_fit = np.linspace(df['Tamanho da lista'].min(), df['Tamanho da lista'].max(), 100)
    plt.plot(x_fit, p(x_fit), color='red', linestyle='--', linewidth=2, label='Linha de Tendência')

    plt.title('Relação Quadrática entre Tamanho da Lista e Tempo de Execução', fontsize=16, weight='bold')
    plt.xlabel('Tamanho da Lista', fontsize=14)
    plt.ylabel('Tempo Médio (s)', fontsize=14)
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.legend()
    plt.tight_layout()
    plt.show()

plot_quadratico(df)
# Out:
#      <input type="file" id="files-911c0a9a-f678-4623-b296-8c557e5f7904" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-911c0a9a-f678-4623-b296-8c557e5f7904">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
def calcula_media_tempo(df):
    media_df = df.groupby('Tamanho da lista')['Tempo Médio (s)'].mean().reset_index()
    return media_df

def plot_barras_com_tendencia(df):
    media_df = calcula_media_tempo(df)

    fig, ax = plt.subplots(figsize=(12, 6))

    bars = ax.bar(media_df['Tamanho da lista'], media_df['Tempo Médio (s)'], color='#1f77b4', edgecolor='black')

    z = np.polyfit(media_df['Tamanho da lista'], media_df['Tempo Médio (s)'], 2)
    p = np.poly1d(z)

    x_fit = np.linspace(media_df['Tamanho da lista'].min(), media_df['Tamanho da lista'].max(), 100)
    ax.plot(x_fit, p(x_fit), color='red', linestyle='--', linewidth=2, label='Linha de Tendência')

    ax.set_xlabel('Tamanho da Lista', fontsize=14)
    ax.set_title('Média do Tempo por Tamanho da Lista com Linha de Tendência', fontsize=16, fontweight='bold')

    ax.set_ylim(0, media_df['Tempo Médio (s)'].max() * 1.4)

    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_linewidth(0.8)
    ax.spines['bottom'].set_linewidth(0.8)
    ax.grid(axis='y', linestyle='--', alpha=0.7)

    ax.legend()

    plt.subplots_adjust(top=0.95, bottom=0.15, left=0.1, right=0.9)
    plt.show()

plot_barras_com_tendencia(df)

# %%
#Melhor Caso Merge

uploaded = files.upload()
df = pd.read_csv(list(uploaded.keys())[0])

def plot_quadratico(df):
    plt.figure(figsize=(12, 6))
    plt.scatter(df['Tamanho da lista'], df['Tempo Médio (s)'], color='skyblue', alpha=0.7, edgecolor='black', label='Pontos Individuais')

    z = np.polyfit(df['Tamanho da lista'], df['Tempo Médio (s)'], 2)
    p = np.poly1d(z)

    x_fit = np.linspace(df['Tamanho da lista'].min(), df['Tamanho da lista'].max(), 100)
    plt.plot(x_fit, p(x_fit), color='red', linestyle='--', linewidth=2, label='Linha de Tendência')

    plt.title('Relação Quadrática entre Tamanho da Lista e Tempo de Execução', fontsize=16, weight='bold')
    plt.xlabel('Tamanho da Lista', fontsize=14)
    plt.ylabel('Tempo Médio (s)', fontsize=14)
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.legend()
    plt.tight_layout()
    plt.show()

plot_quadratico(df)
# Out:
#      <input type="file" id="files-85e55cd6-bdcc-4526-87f2-246ec7667d9e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-85e55cd6-bdcc-4526-87f2-246ec7667d9e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
def calcula_media_tempo(df):
    media_df = df.groupby('Tamanho da lista')['Tempo Médio (s)'].mean().reset_index()
    return media_df

def plot_barras_com_tendencia(df):
    media_df = calcula_media_tempo(df)

    fig, ax = plt.subplots(figsize=(12, 6))

    bars = ax.bar(media_df['Tamanho da lista'], media_df['Tempo Médio (s)'], color='#1f77b4', edgecolor='black')

    z = np.polyfit(media_df['Tamanho da lista'], media_df['Tempo Médio (s)'], 2)
    p = np.poly1d(z)

    x_fit = np.linspace(media_df['Tamanho da lista'].min(), media_df['Tamanho da lista'].max(), 100)
    ax.plot(x_fit, p(x_fit), color='red', linestyle='--', linewidth=2, label='Linha de Tendência')

    ax.set_xlabel('Tamanho da Lista', fontsize=14)
    ax.set_title('Média do Tempo por Tamanho da Lista com Linha de Tendência', fontsize=16, fontweight='bold')

    ax.set_ylim(0, media_df['Tempo Médio (s)'].max() * 1.4)

    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_linewidth(0.8)
    ax.spines['bottom'].set_linewidth(0.8)
    ax.grid(axis='y', linestyle='--', alpha=0.7)

    ax.legend()

    plt.subplots_adjust(top=0.95, bottom=0.15, left=0.1, right=0.9)
    plt.show()

plot_barras_com_tendencia(df)
